# %%
from graphviz import Digraph
from graph import graph, node

# %%
g = graph()
g['A'] = 'B'
g['B'] = 'A'
g['C'] = 'C'
g['D'] = 'B'
g['D'] = 'A'
g['D'] = 'C'
g['A'] = 'D'
g.draw()

# %%
del g['A']

# %%
g.draw()
